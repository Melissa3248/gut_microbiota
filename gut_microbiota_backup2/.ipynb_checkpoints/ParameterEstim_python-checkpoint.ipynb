# %%
import torch 
import torchdiffeq
import torch.nn as nn
import math
import numpy as np
#from torchdiffeq import odeint as odeint
# Out:
# /global/common/software/nersc/pm-2022q3/sw/python/3.9-anaconda-2021.11/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#phi(a, gamma_a) = a ./ (a + gamma_a)

class model(nn.Module):
    def __init__(self, params, device):
        super().__init__()
        self.params = nn.Parameter(params)
        
    def phi(self, u, γu):
        return u / (u+γu)
        
    def forward(self, t, u):
        βa, βB, βE1, βE2, βh1, βh2, βh3, βM1, βM2, βp, γa, γB, γh, γp, μaE, μaM, μhM, μpB, μpE, q = self.params
        B, E, M, a, h, p = u
        
        
        nextB = βB*self.phi(p,γp)*B - q*B
        nextE = (βE1*self.phi(a, γa) + βE2*(1-self.phi(B, γB))*self.phi(p, γp))*E - q*E
        nextM = (βM1*self.phi(a, γa) + βM2*self.phi(h, γh))*M - q*M

        nexta = βa*self.phi(p, γp)*B - q*a - (μaE*E + μaM*M)*self.phi(a, γa)
        nexth = βh1*self.phi(a, γa)*E + βh2*self.phi(p, γp)*B - q*h- μhM*self.phi(h, γh)*M + βh3*(1-self.phi(B, γB))*self.phi(p, γp)*E 
            
        nextp = βp*q*(math.cos(t)+1)**3 - q*p - (μpB*B + μpE*E)*self.phi(p, γp)
        
        return torch.stack([nextB,nextE, nextM, nexta, nexth, nextp])

# %%
#phi(a, gamma_a) = a ./ (a + gamma_a)

class old_model(nn.Module):
    def __init__(self, params, device):
        super().__init__()
        self.params = nn.Parameter(params)
        
    def phi(self, u, γu):
        return u / (u+γu)
        
    def forward(self, t, u):
        βa, βB, βE1, βE2, βh1, βh2, βh3, βM1, βM2, βp, γa, γB, γh, γp, μaE, μaM, μhM, μpB, μpE, q = self.params
        B, E, M, a, h, p = u
        
        nextB = βB*self.phi(p,γp)*B - q*B
        nextE = (βE1*self.phi(a, γa) + βE2*(1-self.phi(B, γB))*self.phi(p, γp))*E - q*E
        nextM = (βM1*self.phi(a, γa) + βM2*self.phi(h, γh))*M - q*M

        nexta = βa*self.phi(p, γp)*B - q*a - (μaE*E + μaM*M)*self.phi(a, γa)
        nexth = βh1*self.phi(a, γa)*E + βh2*self.phi(p, γp)*B + βh3*(1-self.phi(B, γB))*self.phi(p, γp)*E - q*h- μhM*M*self.phi(h, γh)  
            
        nextp = βp*q*(math.cos(t)+1)**3 - q*p - μpB*B*self.phi(p, γp) - μpE*E*self.phi(p, γp)
        
        return torch.stack([nextB,nextE, nextM, nexta, nexth, nextp])

# %%
u0 = torch.tensor([0.0004706, 0.0004706, 0.0004706, 9.7079, 7.9551, 32.061])
tspan = (0.0,500.0);
p = torch.nn.Parameter(torch.tensor([3e5, # betaa 1e7
    1.2, # betab
    0.8, # betaE1
    0.6, # betaE2
    400, #betah1 150
    33000, #betah2
    10000,  #betah3                   
    0.827, #betaM1 0.8
    0.5, #betaM2
    1000, #betap 10000
    200, #gammaa
    10, # gammaB
    150, #gammah
    400, # gammap 400
    50000, # muaE 25000
    40000, # muaM 50000
    3000, # muhM 400
    200000, #mupB
    5000000, #mupE
    0.05]),requires_grad = False) #0.1 # q

# %%
device = 'cpu'
diffeq = old_model(p, device)

# %%
from torchdiffeq import odeint_adjoint
from torchdiffeq import odeint
import matplotlib.pyplot as plt
adjoint = True
ode_integrator = odeint_adjoint if adjoint else odeint

# %%
n_points = 400
tmax = 400
X = ode_integrator(diffeq, u0, torch.linspace(0, tmax, n_points, device=device))

# %%
X.shape
# Out:
# torch.Size([400, 6])

# %%
order = ["B", "E", "M", "a", "h", "p"]
for i in range(6):
    #plt.plot(np.arange(0,300, 3/5), X[:,i].detach())
    
    plt.plot(range(n_points), X[:,i].detach())
    if i >2:
        plt.hlines(u0[i], 0,n_points, colors = ['black'])
    plt.title("{}".format(order[i]))
    plt.show()

# %%
order = ["B", "E", "M", "a", "h", "p"]
for i in range(6):
    #plt.plot(np.arange(0,300, 3/5), X[:,i].detach())
    plt.plot(range(n_points), orig_solution[:,i].detach())
    plt.title("{}".format(order[i]))
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_373258/2663324677.py in <module>
#       2 for i in range(6):
#       3     #plt.plot(np.arange(0,300, 3/5), X[:,i].detach())
# ----> 4     plt.plot(range(n_points), orig_solution[:,i].detach())
#       5     plt.title("{}".format(order[i]))
#       6     plt.show()
#
# NameError: name 'orig_solution' is not defined

# %%
# truth = u0; t_start = 400; t_end = 500; weight = u0
def loss(sol, truth, t_start, t_end, weight):
    """ loss computes a weighted mean squared error loss between a prediction (averaged across timepoints t_start to t_end) and ground truth weighted by a weight vector
    truth (Vector): vector containing the ground truth
    pred (Matrix): matrix with shape (variables, timepoints)
    t_start (integer): first timepoint to pull to compute an average across time
    t_end (integer): last timepoint to pull to compute an average across time
    """
    #print((truth-torch.mean(sol[t_start:t_end,:], dim=0))**2 /weight)
    #return sum((truth-torch.mean(sol[t_start:t_end,:], dim=0))**2 /weight )#(u0-mean(sol[:,t_start:t_end], dims=2))./ weight
    s = torch.abs(sum(truth[:3]) - sum(torch.mean(sol[t_start:t_end,:3], dim =0)) )/sum(weight[:3])
    print (s, torch.abs((truth[3:]-torch.mean(sol[t_start:t_end,3:], dim=0))) /weight[3:])
    return (s + torch.sum(torch.abs((truth[3:]-torch.mean(sol[t_start:t_end,3:], dim=0))) /weight[3:]))/4  #+ torch.var(sol[t_start:t_end,5])/weight[5]#(u0-mean(sol[:,t_start:t_end], dims=2))./ weight

# %%
loss(X,u0,300,500, u0)
# Out:
# tensor(0.4642, grad_fn=<DivBackward0>) tensor([0.0847, 0.0370, 0.0117], grad_fn=<DivBackward0>)
# tensor(0.1494, grad_fn=<DivBackward0>)

# %%
n_epochs = 1000

optimizer = torch.optim.Adam([{'params':diffeq.parameters(), 'lr':1e-2}])
lambda1 = lambda epoch: (epoch-9)**(-1) if epoch >=100 else 1
scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=[lambda1])

training_loss = []

for epoch in range(n_epochs):
    
    print("epoch", epoch)
    # zero out gradient information
    optimizer.zero_grad()
    
    # get ODE solution for timepoints 0 to 500, 1000 discrete points
    X = ode_integrator(diffeq, u0, torch.linspace(0, 300, 500, device=device))
    
    # compute the loss 
    l = loss(X,u0,300,500, u0)
    print(l)
    
    # store loss information, do not track gradient information for this operation
    with torch.no_grad():
        training_loss.append(l.detach().cpu())
    
    # compute gradient information
    l.backward()
    
    # update parameters based on gradient information
    optimizer.step()
    
    # update scheduler
    scheduler.step()
# Out:
# epoch 0
# tensor(0.2117, grad_fn=<DivBackward0>)
# epoch 1
# tensor(0.1166, grad_fn=<DivBackward0>)
# epoch 2
# tensor(0.1181, grad_fn=<DivBackward0>)
# epoch 3
# tensor(0.1050, grad_fn=<DivBackward0>)
# epoch 4
# tensor(0.0933, grad_fn=<DivBackward0>)
# epoch 5
# tensor(0.0996, grad_fn=<DivBackward0>)
# epoch 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_373258/1646905203.py in <module>
#      14
#      15     # get ODE solution for timepoints 0 to 500, 1000 discrete points
# ---> 16     X = ode_integrator(diffeq, u0, torch.linspace(0, 300, 500, device=device))
#      17
#      18     # compute the loss
#
# ~/.local/lib/python3.9/site-packages/torchdiffeq/_impl/adjoint.py in odeint_adjoint(func, y0, t, rtol, atol, method, options, event_fn, adjoint_rtol, adjoint_atol, adjoint_method, adjoint_options, adjoint_params)
#     196     handle_adjoint_norm_(adjoint_options, shapes, state_norm)
#     197
# --> 198     ans = OdeintAdjointMethod.apply(shapes, func, y0, t, rtol, atol, method, options, event_fn, adjoint_rtol, adjoint_atol,
#     199                                     adjoint_method, adjoint_options, t.requires_grad, *adjoint_params)
#     200
#
# ~/.local/lib/python3.9/site-packages/torchdiffeq/_impl/adjoint.py in forward(ctx, shapes, func, y0, t, rtol, atol, method, options, event_fn, adjoint_rtol, adjoint_atol, adjoint_method, adjoint_options, t_requires_grad, *adjoint_params)
#      23
#      24         with torch.no_grad():
# ---> 25             ans = odeint(func, y0, t, rtol=rtol, atol=atol, method=method, options=options, event_fn=event_fn)
#      26
#      27             if event_fn is None:
#
# ~/.local/lib/python3.9/site-packages/torchdiffeq/_impl/odeint.py in odeint(func, y0, t, rtol, atol, method, options, event_fn)
#      75
#      76     if event_fn is None:
# ---> 77         solution = solver.integrate(t)
#      78     else:
#      79         event_t, solution = solver.integrate_until_event(t[0], event_fn)
#
# ~/.local/lib/python3.9/site-packages/torchdiffeq/_impl/solvers.py in integrate(self, t)
#      28         self._before_integrate(t)
#      29         for i in range(1, len(t)):
# ---> 30             solution[i] = self._advance(t[i])
#      31         return solution
#      32
#
# ~/.local/lib/python3.9/site-packages/torchdiffeq/_impl/rk_common.py in _advance(self, next_t)
#     192         while next_t > self.rk_state.t1:
#     193             assert n_steps < self.max_num_steps, 'max_num_steps exceeded ({}>={})'.format(n_steps, self.max_num_steps)
# --> 194             self.rk_state = self._adaptive_step(self.rk_state)
#     195             n_steps += 1
#     196         return _interp_evaluate(self.rk_state.interp_coeff, self.rk_state.t0, self.rk_state.t1, next_t)
#
# ~/.local/lib/python3.9/site-packages/torchdiffeq/_impl/rk_common.py in _adaptive_step(self, rk_state)
#     253         # trigger both. (i.e. interleaving them would be wrong.)
#     254
# --> 255         y1, f1, y1_error, k = _runge_kutta_step(self.func, y0, f0, t0, dt, t1, tableau=self.tableau)
#     256         # dtypes:
#     257         # y1.dtype == self.y0.dtype
#
# ~/.local/lib/python3.9/site-packages/torchdiffeq/_impl/rk_common.py in _runge_kutta_step(func, y0, f0, t0, dt, t1, tableau)
#      74             perturb = Perturb.NONE
#      75         yi = y0 + torch.sum(k[..., :i + 1] * (beta_i * dt), dim=-1).view_as(f0)
# ---> 76         f = func(ti, yi, perturb=perturb)
#      77         k = _UncheckedAssign.apply(k, f, (..., i + 1))
#      78
#
# ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.local/lib/python3.9/site-packages/torchdiffeq/_impl/misc.py in forward(self, t, y, perturb)
#     187             # Do nothing.
#     188             pass
# --> 189         return self.base_func(t, y)
#     190
#     191
#
# ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.local/lib/python3.9/site-packages/torchdiffeq/_impl/misc.py in forward(self, t, y, perturb)
#     187             # Do nothing.
#     188             pass
# --> 189         return self.base_func(t, y)
#     190
#     191
#
# ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /tmp/ipykernel_373258/619971260.py in forward(self, t, u)
#      18
#      19         nexta = βa*self.phi(p, γp)*B - q*a - (μaE*E + μaM*M)*self.phi(a, γa)
# ---> 20         nexth = βh1*self.phi(a, γa)*E + βh2*self.phi(p, γp)*B + βh3*(1-self.phi(B, γB))*self.phi(p, γp)*E - q*h- μhM*M*self.phi(h, γh)
#      21
#      22         nextp = βp*q*(math.cos(t)+1)**3 - q*p - μpB*B*self.phi(p, γp) - μpE*E*self.phi(p, γp)
#
# KeyboardInterrupt:

# %%
#dir(diffeq)
#torch.save(diffeq.params,"params.pt")

# %%
plt.plot(range(7), training_loss)

# %%
X = ode_integrator(diffeq, u0, torch.linspace(0, 300, 500, device=device))

# %%
for i in range(6):
    plt.plot(range(500), X[:,i].detach())
    plt.show()

# %%
for i in p:
    print(i)
# Out:
# tensor(300000.)
# tensor(1.1836)
# tensor(0.8081)
# tensor(0.6070)
# tensor(399.9634)
# tensor(32999.9688)
# tensor(9999.9580)
# tensor(0.8155)
# tensor(0.4857)
# tensor(999.9784)
# tensor(200.0436)
# tensor(10.0060)
# tensor(150.0120)
# tensor(400.0551)
# tensor(49999.9609)
# tensor(39999.9688)
# tensor(3000.0264)
# tensor(200000.0156)
# tensor(5000000.)
# tensor(0.0838)

# %%
import torch 
import torchdiffeq
import torch.nn as nn
import math
import numpy as np
#from torchdiffeq import odeint as odeint

# %%
#phi(a, gamma_a) = a ./ (a + gamma_a)

class model(nn.Module):
    def __init__(self, params, device):
        super().__init__()
        self.params = nn.Parameter(params)
        
    def phi(self, u, γu):
        return u / (u+γu)
        
    def forward(self, t, u):
        βa, βB, βE1, βE2, βh1, βh2, βM1, βM2, βp, γa, γB, γh, γp, μaE, μaM, μhM, μpB, μpE, q = self.params
        B, E, M, a, h, p = u
        
        
        nextB = βB*self.phi(p,γp)*B - q*B
        nextE = (βE1*self.phi(a, γa) + βE2*(1-self.phi(B, γB))*self.phi(p, γp))*E - q*E
        nextM = (βM1*self.phi(a, γa) + βM2*self.phi(h, γh))*M - q*M

        nexta = βa*self.phi(p, γp)*B - q*a - (μaE*E + μaM*M)*self.phi(a, γa)
        nexth = βh1*self.phi(a, γa)*E + βh2*self.phi(p, γp)*B - q*h- μhM*self.phi(h, γh)*M
        nextp = βp*q*(math.cos(t)+1)**3 - q*p - (μpB*B + μpE*E)*self.phi(p, γp)
        
        return torch.stack([nextB,nextE, nextM, nexta, nexth, nextp])

# %%
u0 = torch.tensor([0.0004706, 0.0004706, 0.0004706, 9.7079, 7.9551, 32.061])
tspan = (0.0,500.0);
p = torch.nn.Parameter(torch.tensor([0.5, # betaa
    0.5, # betab
    0.5, # betaE1
    0.5, # betaE2
    0.5, #betah1
    0.5, #betah2
    0.5, #betaM1
    0.5, #betaM2
    30, #30, #betap
    10, #gammaa
    1e-4, # gammaB
    10, #gammah
    30, # gammap
    0.5, # muaE
    0.5, # muaM
    0.5, # muhM
    0.5, #mupB
    0.5, #mupE
    0.1]),requires_grad = True) #0.1 # q

# %%
device = 'cpu'
diffeq = model(p, device)

# %%
diffeq(1,u0)
# Out:
# tensor([ 7.4497e-05,  9.0150e-05,  1.7310e-04, -9.7090e-01, -7.9538e-01,
#          7.7569e+00], grad_fn=<StackBackward0>)

# %%
from torchdiffeq import odeint_adjoint
from torchdiffeq import odeint
adjoint = True
ode_integrator = odeint_adjoint if adjoint else odeint

# %%
X = ode_integrator(diffeq, u0, torch.linspace(0, 300, 500, device=device))

# %%
X.shape
# Out:
# torch.Size([500, 6])

# %%
import matplotlib.pyplot as plt

# %%
len(np.arange(0,300, 3/5))
# Out:
# 500

# %%
for i in range(6):
    #plt.plot(np.arange(0,300, 3/5), X[:,i].detach())
    plt.plot(range(500), X[:,i].detach())
    plt.show()

# %%
#truth = u0; t_start = 400; t_end = 500; weight = u0
def loss(sol, truth, t_start, t_end, weight):
    """ loss computes a weighted mean squared error loss between a prediction (averaged across timepoints t_start to t_end) and ground truth weighted by a weight vector
    truth (Vector): vector containing the ground truth
    pred (Matrix): matrix with shape (variables, timepoints)
    t_start (integer): first timepoint to pull to compute an average across time
    t_end (integer): last timepoint to pull to compute an average across time
    """
    #print((truth-torch.mean(sol[t_start:t_end,:], dim=0))**2 /weight)
    #return sum((truth-torch.mean(sol[t_start:t_end,:], dim=0))**2 /weight )#(u0-mean(sol[:,t_start:t_end], dims=2))./ weight
    return sum((truth-torch.mean(sol[t_start:t_end,:], dim=0))**2 /weight ) + torch.var(sol[t_start:t_end,5])/weight[5]#(u0-mean(sol[:,t_start:t_end], dims=2))./ weight

# %%
n_epochs = 1000

optimizer = torch.optim.Adam([{'params':diffeq.parameters(), 'lr':1e-1}])
lambda1 = lambda epoch: (epoch-9)**(-1) if epoch >=1000 else 1
scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=[lambda1])

training_loss = []

for epoch in range(n_epochs):
    
    print("epoch", epoch)
    # zero out gradient information
    optimizer.zero_grad()
    
    # get ODE solution for timepoints 0 to 500, 1000 discrete points
    X = ode_integrator(diffeq, u0, torch.linspace(0, 300, 500, device=device))
    
    # compute the loss 
    l = loss(X,u0,300,500, u0)
    print(l)
    
    # store loss information, do not track gradient information for this operation
    with torch.no_grad():
        training_loss.append(l.detach().cpu())
    
    # compute gradient information
    l.backward()
    
    # update parameters based on gradient information
    optimizer.step()
    
    # update scheduler
    scheduler.step()
# Out:
# epoch 0
# tensor(45450484., grad_fn=<AddBackward0>)
# epoch 1
# tensor(6551721., grad_fn=<AddBackward0>)
# epoch 2
# tensor(1450263., grad_fn=<AddBackward0>)
# epoch 3
# tensor(95.3097, grad_fn=<AddBackward0>)
# epoch 4
# tensor(101.6149, grad_fn=<AddBackward0>)
# epoch 5
# tensor(107.2670, grad_fn=<AddBackward0>)
# epoch 6
# tensor(112.2938, grad_fn=<AddBackward0>)
# epoch 7
# tensor(116.7538, grad_fn=<AddBackward0>)
# epoch 8
# tensor(120.7106, grad_fn=<AddBackward0>)
# epoch 9
# tensor(124.2244, grad_fn=<AddBackward0>)
# epoch 10
# tensor(127.3500, grad_fn=<AddBackward0>)
# epoch 11
# tensor(130.1349, grad_fn=<AddBackward0>)
# epoch 12
# tensor(132.6218, grad_fn=<AddBackward0>)
# epoch 13
# tensor(134.8462, grad_fn=<AddBackward0>)
# epoch 14
# tensor(136.8391, grad_fn=<AddBackward0>)
# epoch 15
# tensor(138.6272, grad_fn=<AddBackward0>)
# epoch 16
# tensor(140.2347, grad_fn=<AddBackward0>)
# epoch 17
# tensor(141.6818, grad_fn=<AddBackward0>)
# epoch 18
# tensor(142.9859, grad_fn=<AddBackward0>)
# epoch 19
# tensor(144.1621, grad_fn=<AddBackward0>)
# epoch 20
# tensor(145.2248, grad_fn=<AddBackward0>)
# epoch 21
# tensor(146.1852, grad_fn=<AddBackward0>)
# epoch 22
# tensor(147.0544, grad_fn=<AddBackward0>)
# epoch 23
# tensor(147.8410, grad_fn=<AddBackward0>)
# epoch 24
# tensor(148.5537, grad_fn=<AddBackward0>)
# epoch 25
# tensor(149.1997, grad_fn=<AddBackward0>)
# epoch 26
# tensor(149.7856, grad_fn=<AddBackward0>)
# epoch 27
# tensor(150.3172, grad_fn=<AddBackward0>)
# epoch 28
# tensor(150.7995, grad_fn=<AddBackward0>)
# epoch 29
# tensor(151.2376, grad_fn=<AddBackward0>)
# epoch 30
# tensor(151.6355, grad_fn=<AddBackward0>)
# epoch 31
# tensor(151.9966, grad_fn=<AddBackward0>)
# epoch 32
# tensor(152.3248, grad_fn=<AddBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_524848/3554818396.py in <module>
#      25
#      26     # compute gradient information
# ---> 27     l.backward()
#      28
#      29     # update parameters based on gradient information
#
# ~/.local/lib/python3.9/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     394                 create_graph=create_graph,
#     395                 inputs=inputs)
# --> 396         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     397
#     398     def register_hook(self, hook):
#
# ~/.local/lib/python3.9/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     171     # some Python versions print out the first line of a multi-line function
#     172     # calls in the traceback and some print out the last line
# --> 173     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
# ~/.local/lib/python3.9/site-packages/torch/autograd/function.py in apply(self, *args)
#     251                                "of them.")
#     252         user_fn = vjp_fn if vjp_fn is not Function.vjp else backward_fn
# --> 253         return user_fn(self, *args)
#     254
#     255     def apply_jvp(self, *args):
#
# ~/.local/lib/python3.9/site-packages/torchdiffeq/_impl/adjoint.py in backward(ctx, *grad_y)
#     124
#     125                 # Run the augmented system backwards in time.
# --> 126                 aug_state = odeint(
#     127                     augmented_dynamics, tuple(aug_state),
#     128                     t[i - 1:i + 1].flip(0),
#
# ~/.local/lib/python3.9/site-packages/torchdiffeq/_impl/odeint.py in odeint(func, y0, t, rtol, atol, method, options, event_fn)
#      75
#      76     if event_fn is None:
# ---> 77         solution = solver.integrate(t)
#      78     else:
#      79         event_t, solution = solver.integrate_until_event(t[0], event_fn)
#
# ~/.local/lib/python3.9/site-packages/torchdiffeq/_impl/solvers.py in integrate(self, t)
#      28         self._before_integrate(t)
#      29         for i in range(1, len(t)):
# ---> 30             solution[i] = self._advance(t[i])
#      31         return solution
#      32
#
# ~/.local/lib/python3.9/site-packages/torchdiffeq/_impl/rk_common.py in _advance(self, next_t)
#     192         while next_t > self.rk_state.t1:
#     193             assert n_steps < self.max_num_steps, 'max_num_steps exceeded ({}>={})'.format(n_steps, self.max_num_steps)
# --> 194             self.rk_state = self._adaptive_step(self.rk_state)
#     195             n_steps += 1
#     196         return _interp_evaluate(self.rk_state.interp_coeff, self.rk_state.t0, self.rk_state.t1, next_t)
#
# ~/.local/lib/python3.9/site-packages/torchdiffeq/_impl/rk_common.py in _adaptive_step(self, rk_state)
#     253         # trigger both. (i.e. interleaving them would be wrong.)
#     254
# --> 255         y1, f1, y1_error, k = _runge_kutta_step(self.func, y0, f0, t0, dt, t1, tableau=self.tableau)
#     256         # dtypes:
#     257         # y1.dtype == self.y0.dtype
#
# ~/.local/lib/python3.9/site-packages/torchdiffeq/_impl/rk_common.py in _runge_kutta_step(func, y0, f0, t0, dt, t1, tableau)
#      74             perturb = Perturb.NONE
#      75         yi = y0 + torch.sum(k[..., :i + 1] * (beta_i * dt), dim=-1).view_as(f0)
# ---> 76         f = func(ti, yi, perturb=perturb)
#      77         k = _UncheckedAssign.apply(k, f, (..., i + 1))
#      78
#
# ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.local/lib/python3.9/site-packages/torchdiffeq/_impl/misc.py in forward(self, t, y, perturb)
#     187             # Do nothing.
#     188             pass
# --> 189         return self.base_func(t, y)
#     190
#     191
#
# ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.local/lib/python3.9/site-packages/torchdiffeq/_impl/misc.py in forward(self, t, y)
#     157
#     158     def forward(self, t, y):
# --> 159         return self.mul * self.base_func(-t, y)
#     160
#     161
#
# ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.local/lib/python3.9/site-packages/torchdiffeq/_impl/misc.py in forward(self, t, y)
#     136
#     137     def forward(self, t, y):
# --> 138         f = self.base_func(t, _flat_to_shape(y, (), self.shapes))
#     139         return torch.cat([f_.reshape(-1) for f_ in f])
#     140
#
# ~/.local/lib/python3.9/site-packages/torchdiffeq/_impl/adjoint.py in augmented_dynamics(t, y_aug)
#      86                     # doesn't necessarily even exist if there is piecewise structure in time), so turning off gradients
#      87                     # wrt t here means we won't compute that if we don't need it.
# ---> 88                     func_eval = func(t if t_requires_grad else t_, y)
#      89
#      90                     # Workaround for PyTorch bug #39784
#
# ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.local/lib/python3.9/site-packages/torchdiffeq/_impl/misc.py in forward(self, t, y, perturb)
#     187             # Do nothing.
#     188             pass
# --> 189         return self.base_func(t, y)
#     190
#     191
#
# ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /tmp/ipykernel_524848/2194106653.py in forward(self, t, u)
#      14
#      15
# ---> 16         nextB = betab*self.phi(p,gammap)*B - q*B
#      17         nextE = (betaE1*self.phi(a, gammaa) + betaE2*(1-self.phi(B, gammaB))*self.phi(p, gammap))*E - q*E
#      18         nextM = (betaM1*self.phi(a, gammaa) + betaM2*self.phi(h, gammah))*M - q*M
#
# /tmp/ipykernel_524848/2194106653.py in phi(self, u, gammau)
#       7
#       8     def phi(self, u, gammau):
# ----> 9         return u / (u+gammau)
#      10
#      11     def forward(self, t, u):
#
# KeyboardInterrupt:

# %%
#dir(diffeq)
#torch.save(diffeq.params,"params.pt")

# %%
plt.plot(range(33), training_loss)

# %%
X = ode_integrator(diffeq, u0, torch.linspace(0, 300, 500, device=device))

# %%
for i in range(6):
    plt.plot(range(500), X[:,i].detach())
    plt.show()
